# %% [markdown]
# # 객체지향

# %%
import random

class Array(object):
    def __init__(self):
        self.numbers = [ [ ], [ ], [ ] ]
        for row in range(3):
            for col in range(4):
                self.numbers[row].append(random.randint(1, 12))

    def printList(self):
        for row in range(len(self.numbers)):
            for col in range(len(self.numbers[row])):
                print(self.numbers[row][col], sep = " ", end = " ")
            print()

    def findMatchNumbers(self, compareObject):
        count = 0
        for row in range(len(self.numbers)):
            for col in range(len(self.numbers[row])):
                if (self.numbers[row][col] == compareObject[row][col]):
                    count += 1
                    print("일치하는 숫자 : [{r}][{c}] = {v}".foramt(row,col, self.numbers[row][col]))
        print("일치하는 숫자 개수 :", count)

# %%
if __name__ == '__main__':
    source = Array()
    target = Array()
    print("## 첫번째 Array 출력")
    source.printList()
    print("## 두번째 Array 출력")
    target.printList()
    source.findMatchNumbers(target.numbers)
# Out:
# ## 첫번째 Array 출력
# 10 2 4 3
# 5 2 10 7
# 4 10 6 1
# ## 두번째 Array 출력
# 9 5 1 2
# 11 8 1 3
# 2 7 3 6
# 일치하는 숫자 개수 : 0

# %%
import random
class Array(object):
    def __init__(self):
        self.numbers =[[],[],[]]
        for row in range(3):
            for col in range(4):
                self.numbers[row].append(random.randint(1, 12))
        #print(self.numbers)
   
    def printList(self):
        for row in range(len(self.numbers)):
            for col in range(len(self.numbers[row])) :
                print(self.numbers[row][col], sep=" ", end=" ")
            print()

    def findMatchNumbers(self, compareList):
        count = 0
        for row in range(len(self.numbers)):
            for col in range(len(self.numbers[row])) :
                if (self.numbers[row][col] == compareList[row][col]) :
                    count+=1
                    print("일치하는 숫자 : [", row, "][", col, "]=", self.numbers[row][col])
        print("일치하는 숫자 개수 :" , count)

# %%
if __name__ == '__main__':
    source = Array()
    target = Array()
    print("## 첫번째 Array 출력")
    source.printList()
    print("## 두번째 Array 출력")
    target.printList()
    source.findMatchNumbers(target.numbers)
# Out:
# ## 첫번째 Array 출력
# 2 7 2 3
# 3 9 12 4
# 5 3 7 8
# ## 두번째 Array 출력
# 10 3 6 5
# 7 4 9 4
# 11 9 8 6
# 일치하는 숫자 : [ 1 ][ 3 ]= 4
# 일치하는 숫자 개수 : 1

# %%
import random

class Array(object):
  def __init__(self):
    self.numbers = [[], [], []]
    for row in range(3):
      for col in range(4):
        self.numbers[row].append(random.randint(1, 12))

  def printList(self):
    for row in range(len(self.numbers)):
      for col in range(len(self.numbers[row])):
        print(self.numbers[row][col], sep=' ', end=' ')
      print()

  def findMatchNumbers(self, compareList):
    count = 0
    for row in range(len(self.numbers)):
      for col in range(len(self.numbers[row])):
        if (self.numbers[row][col] == compareList[row][col]):
          count += 1
          print('일치하는 숫자:[",row,"][",col,"]=', self.numbers[row][col])

    print("일치하는 숫자 개수:", count)

# %%
if __name__ == '__main__':
    source = Array()
    target = Array()
    print("## 첫번째 Array 출력")
    source.printList()
    print("## 두번째 Array 출력")
    target.printList()
    source.findMatchNumbers(target.numbers)
# Out:
# ## 첫번째 Array 출력
# 5 10 4 5
# 11 10 7 3
# 2 12 10 3
# ## 두번째 Array 출력
# 10 11 7 9
# 11 11 8 9
# 10 5 5 2
# 일치하는 숫자:[",row,"][",col,"]= 11
# 일치하는 숫자 개수: 1

# %% [markdown]
# # Pandas

# %%
import pandas as pd

text_test = pd.read_csv('C:/workspace/basic/test_text_file.txt', sep = '|')
print(type(text_test))
print(text_test.shape)
print(text_test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (3, 5)
#    ID    A  B  C    D
# 0  C1  1.0  2  3  NaN
# 1  C2  5.0  ?  7  8.0
# 2  C3  NaN  3  5  7.0

# %%
text_test = pd.read_csv('C:/workspace/basic/test_text_file.txt', sep = '|', index_col = 0)

print(text_test)
# Out:
#       A  B  C    D
# ID
# C1  1.0  2  3  NaN
# C2  5.0  ?  7  8.0
# C3  NaN  3  5  7.0

# %%
text_test = pd.read_csv('C:/workspace/basic/text_without_column_name.txt')
# names = (['ID', 'A', 'B', 'C', 'D'], header = None, index_col='ID')
print(text_test)
# Out:
#       ID|A|B|C|D
# 0   C1|1|2|3|nan
# 1     C2|5|?|7|8
# 2  C3|null|3|5|7

# %%
text_test = pd.read_csv("C:/workspace/basic/test_csv_file.csv", skiprows = [1, 2])
print(text_test)
# Out:
#    ID LAST_NAME  AGE
# 0   3       LEE   41
# 1   4      PARK   19
# 2   5       LIM   36

# %%
text_test = pd.read_csv("C:/workspace/basic/test_csv_file.csv", nrows = 3)
print(text_test)
# Out:
#    ID LAST_NAME  AGE
# 0   1       KIM   30
# 1   2      CHOI   25
# 2   3       LEE   41

# %%
text_test = pd.read_csv("C:/workspace/basic/test_text_file.txt")
na_values = ['?', '??', 'N/A', 'NA', 'nan', 'NaN', '-nan', '-NaN', 'null']
print(text_test)
# Out:
#       ID|A|B|C|D
# 0   C1|1|2|3|nan
# 1     C2|5|?|7|8
# 2  C3|null|3|5|7

# %%
csv_test = pd.read_csv("C:/workspace/basic/test_csv_file.csv")
dtype = {"ID": int, "LAST_NAME": str, "AGE": float}
print(csv_test)
# Out:
#    ID LAST_NAME  AGE
# 0   1       KIM   30
# 1   2      CHOI   25
# 2   3       LEE   41
# 3   4      PARK   19
# 4   5       LIM   36

# %%
csv_test = pd.read_csv('C:/workspace/basic/test_csv_file.csv')
print(type(csv_test["ID"]))
print(type(csv_test["LAST_NAME"]))
print(type(csv_test["AGE"]))

csv_test2 = pd.read_csv('C:/workspace/basic/test_csv_file.csv', dtype = {"ID": int, "LAST_NAME": str, "AGE": float})

print(type(csv_test2.LAST_NAME))
print(type(csv_test2.ID))
print(type(csv_test2.AGE))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
csv_test = pd.read_csv('C:/workspace/basic/test_csv_file.csv')
print(type(csv_test["ID"]))
print(type(csv_test["LAST_NAME"]))
print(type(csv_test["AGE"]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
csv_test2 = pd.read_csv('C:/workspace/basic/test_csv_file.csv',
                        dtype = {"ID": int, "LAST_NAME": str, "AGE": float})

print(type(csv_test2.LAST_NAME))
print(type(csv_test2.ID))
print(type(csv_test2.AGE))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
import pandas as pd
csv_test = pd.read_csv('C:/workspace/basic/test_csv_file.csv')
print(type(csv_test['ID']))   #컬럼이름을 키로 사용
print(type(csv_test['LAST_NAME']))
print(type(csv_test['AGE']))
print(csv_test.info())

csv_test2 = pd.read_csv('C:/workspace/basic/test_csv_file.csv',
dtype = {"ID": int, "LAST_NAME": str, "AGE": float} )
print(type(csv_test['ID'] ))
print(type(csv_test['LAST_NAME'] ))
print(type(csv_test['AGE'] ))
print(csv_test.info())
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         5 non-null      int64
#  1   LAST_NAME  5 non-null      object
#  2   AGE        5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes
# None
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         5 non-null      int64
#  1   LAST_NAME  5 non-null      object
#  2   AGE        5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes
# None

# %%
csv_test2 = pd.read_csv('C:/workspace/basic/test_csv_file.csv',
dtype = {"ID": int, "LAST_NAME": str, "AGE": float} )
print(type(csv_test2['ID'] ))
print(type(csv_test2['LAST_NAME'] ))
print(type(csv_test2['AGE'] ))
print(csv_test2.info())
print(csv_test2)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         5 non-null      int32
#  1   LAST_NAME  5 non-null      object
#  2   AGE        5 non-null      float64
# dtypes: float64(1), int32(1), object(1)
# memory usage: 228.0+ bytes
# None
#    ID LAST_NAME   AGE
# 0   1       KIM  30.0
# 1   2      CHOI  25.0
# 2   3       LEE  41.0
# 3   4      PARK  19.0
# 4   5       LIM  36.0

# %%
import pandas as pd

csv_test2 = pd.read_csv('C:/workspace/basic/test_csv_file.csv', dtype = {"ID": int, "LAST_NAME": str, "AGE": float} )
print(type(csv_test2.ID))
print(type(csv_test2.LAST_NAME))
print(type(csv_test2.AGE))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
student_data = { "1.FirstName": "Gildong", "2.LastName": "Hong", "3.Age": 20, "4.University": "Yonsei University", "5.Courses": [
{ "Major": "Statistics", "Classes": ["Probability", "Generalized Linear Model", "Categorical Data Analysis"]
},{ "Minor": "ComputerScience", "Classes": ["Data Structure", "Programming", "Algorithms"]
}
]
}

# %% [markdown]
# # Json

# %%
import json
with open("student_file.json", "w") as json_file:
    json.dump(student_data, json_file)

# %%
import json

st_json = json.dumps(student_data)
print(st_json)
# Out:
# {"1.FirstName": "Gildong", "2.LastName": "Hong", "3.Age": 20, "4.University": "Yonsei University", "5.Courses": [{"Major": "Statistics", "Classes": ["Probability", "Generalized Linear Model", "Categorical Data Analysis"]}, {"Minor": "ComputerScience", "Classes": ["Data Structure", "Programming", "Algorithms"]}]}

# %%
import json

st_json2 = json.dumps(student_data, indent = 4)
print(st_json2)
# Out:
# {
#     "1.FirstName": "Gildong",
#     "2.LastName": "Hong",
#     "3.Age": 20,
#     "4.University": "Yonsei University",
#     "5.Courses": [
#         {
#             "Major": "Statistics",
#             "Classes": [
#                 "Probability",
#                 "Generalized Linear Model",
#                 "Categorical Data Analysis"
#             ]
#         },
#         {
#             "Minor": "ComputerScience",
#             "Classes": [
#                 "Data Structure",
#                 "Programming",
#                 "Algorithms"
#             ]
#         }
#     ]
# }

# %%
import json

st_json3 = json.dumps(student_data, indent = 4, sort_keys = True)
print(st_json3)
# Out:
# {
#     "1.FirstName": "Gildong",
#     "2.LastName": "Hong",
#     "3.Age": 20,
#     "4.University": "Yonsei University",
#     "5.Courses": [
#         {
#             "Classes": [
#                 "Probability",
#                 "Generalized Linear Model",
#                 "Categorical Data Analysis"
#             ],
#             "Major": "Statistics"
#         },
#         {
#             "Classes": [
#                 "Data Structure",
#                 "Programming",
#                 "Algorithms"
#             ],
#             "Minor": "ComputerScience"
#         }
#     ]
# }

# %%
import json

with open("student_file.json", "r") as st_json:
    st_python = json.load(st_json)
    
print(st_python)
# Out:
# {'1.FirstName': 'Gildong', '2.LastName': 'Hong', '3.Age': 20, '4.University': 'Yonsei University', '5.Courses': [{'Major': 'Statistics', 'Classes': ['Probability', 'Generalized Linear Model', 'Categorical Data Analysis']}, {'Minor': 'ComputerScience', 'Classes': ['Data Structure', 'Programming', 'Algorithms']}]}

# %%
import json

st_python2 = json.loads(st_json3)
print(st_python2)
# Out:
# {'1.FirstName': 'Gildong', '2.LastName': 'Hong', '3.Age': 20, '4.University': 'Yonsei University', '5.Courses': [{'Classes': ['Probability', 'Generalized Linear Model', 'Categorical Data Analysis'], 'Major': 'Statistics'}, {'Classes': ['Data Structure', 'Programming', 'Algorithms'], 'Minor': 'ComputerScience'}]}

# %%
import json
import urllib
import pandas as pd
import sys

if sys.version_info[0] == 3:
    from urllib.request import urlopen # for Python 3.x
else:
    from urllib import urlopen # for Python 2.x

with urlopen("http://api.nobelprize.org/v1/prize.json") as url:
        novel_prize_json_file = url.read()
# 읽어온 JSON 포맷 데이터를 Python의 json.loads() 메소드를 이용해서 decoding
novel_prize_json = json.loads(novel_prize_json_file.decode('utf-8'))

print("json데이터를 웹에서 받아와서 메모리에 json객체로 생성 완료함")
# Out:
# json데이터를 웹에서 받아와서 메모리에 json객체로 생성 완료함

# %%
#keys() 메소드로 키를 확인
print(novel_prize_json.keys())
print(novel_prize_json['prizes'][0].keys())
print(novel_prize_json['prizes'][0])
print(json.dumps(novel_prize_json['prizes'][0], indent=4))
#키(keys)를 기준으로 정렬
print(json.dumps(novel_prize_json['prizes'][0], indent=4, sort_keys=True))
# Out:
# dict_keys(['prizes'])
# dict_keys(['year', 'category', 'laureates'])
# {'year': '2020', 'category': 'chemistry', 'laureates': [{'id': '991', 'firstname': 'Emmanuelle', 'surname': 'Charpentier', 'motivation': '"for the development of a method for genome editing"', 'share': '2'}, {'id': '992', 'firstname': 'Jennifer A.', 'surname': 'Doudna', 'motivation': '"for the development of a method for genome editing"', 'share': '2'}]}
# {
#     "year": "2020",
#     "category": "chemistry",
#     "laureates": [
#         {
#             "id": "991",
#             "firstname": "Emmanuelle",
#             "surname": "Charpentier",
#             "motivation": "\"for the development of a method for genome editing\"",
#             "share": "2"
#         },
#         {
#             "id": "992",
#             "firstname": "Jennifer A.",
#             "surname": "Doudna",
#             "motivation": "\"for the development of a method for genome editing\"",
#             "share": "2"
#         }
# ...

# %%
#['prizes'][0] 은 물리학(physics) 노벨상이며, ['prizes'][0]['laureates'] 로 물리학 노벨상 수상자 정보만 선별해서
#DataFrame으로 생성
novel_prize_physics = pd.DataFrame(novel_prize_json['prizes'][0]["laureates"])
print((novel_prize_physics))
print(type(novel_prize_physics))
print(novel_prize_physics.info())

#DataFrame을 만들 때 칼럼 순서를 columns 로 지정
novel_prize_physics = pd.DataFrame(novel_prize_json['prizes'][0]["laureates"], columns = ['id', 'firstname', 'surname', 'share', 'motivation'])
print(novel_prize_physics)
print(novel_prize_physics.info())
# Out:
#     id    firstname      surname  \
# 0  991   Emmanuelle  Charpentier
# 1  992  Jennifer A.       Doudna
#
#                                           motivation share
# 0  "for the development of a method for genome ed...     2
# 1  "for the development of a method for genome ed...     2
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          2 non-null      object
#  1   firstname   2 non-null      object
#  2   surname     2 non-null      object
#  3   motivation  2 non-null      object
#  4   share       2 non-null      object
# dtypes: object(5)
# memory usage: 208.0+ bytes
# None
#     id    firstname      surname share  \
# 0  991   Emmanuelle  Charpentier     2
# 1  992  Jennifer A.       Doudna     2
#
#                                           motivation
# ...

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import sys
if sys.version_info[0] == 3:
    from urllib.request import urlopen
else:
    from urllib import urlopen
url = "https://www.w3schools.com/xml/cd_catalog.xml"


response = urlopen(url).read()
xtree = ET.fromstring(response)
print(xtree)
# Out:
# <Element 'CATALOG' at 0x000002ABFDEBD6D8>

# %%
rows = []
# iterate through each node of the tree
for node in xtree:
    n_title = node.find("TITLE").text
    n_artist = node.find("ARTIST").text
    n_country = node.find("COUNTRY").text
    n_company = node.find("COMPANY").text
    n_price = node.find("PRICE").text
    n_year = node.find("YEAR").text
    rows.append({"title": n_title, "artist": n_artist, "country": n_country, "company": n_company, "price": n_price, "year": n_year})
print(rows)
# Out:
# [{'title': 'Empire Burlesque', 'artist': 'Bob Dylan', 'country': 'USA', 'company': 'Columbia', 'price': '10.90', 'year': '1985'}, {'title': 'Hide your heart', 'artist': 'Bonnie Tyler', 'country': 'UK', 'company': 'CBS Records', 'price': '9.90', 'year': '1988'}, {'title': 'Greatest Hits', 'artist': 'Dolly Parton', 'country': 'USA', 'company': 'RCA', 'price': '9.90', 'year': '1982'}, {'title': 'Still got the blues', 'artist': 'Gary Moore', 'country': 'UK', 'company': 'Virgin records', 'price': '10.20', 'year': '1990'}, {'title': 'Eros', 'artist': 'Eros Ramazzotti', 'country': 'EU', 'company': 'BMG', 'price': '9.90', 'year': '1997'}, {'title': 'One night only', 'artist': 'Bee Gees', 'country': 'UK', 'company': 'Polydor', 'price': '10.90', 'year': '1998'}, {'title': 'Sylvias Mother', 'artist': 'Dr.Hook', 'country': 'UK', 'company': 'CBS', 'price': '8.10', 'year': '1973'}, {'title': 'Maggie May', 'artist': 'Rod Stewart', 'country': 'UK', 'company': 'Pickwick', 'price': '8.50', 'year': '19
# ...

# %%
import numpy as np
import pandas as pd

excel_file = 'C:/workspace/basic/sales_per_region.xlsx'

df_from_excel = pd.read_excel(excel_file, sheet_name = 'Sheet1', header = 2,
                              dtype = {'region': str, 'sales_representative': np.int64, 'sales_amount': float},
                             index_col = 'id', na_values = 'NaN', thousands = ',',
                              nrows = 10, comment = '#')

print(type(df_from_excel))
print(df_from_excel.info())
print(df_from_excel)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 1 to 7
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   region                7 non-null      object
#  1   sales_representative  7 non-null      int64
#  2   sales_amount          7 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 224.0+ bytes
# None
#      region  sales_representative  sales_amount
# id
# 1     seoul                   510        1500.0
# 2    inchon                   430        1260.0
# 3     busan                   320        1090.0
# 4   guangju                   180         550.0
# 5     ulsan                   135         380.0
# 6    sejong                   110         290.0
# 7    jeunju                    83         235.0

# %%
# %%writefile sample1.csv
# c1,    c2,    c3,    c4
# 0.179181, -1.538472, 1.347553, 0.43381
# 1.024209, , -1.281997, 0.49265
# 0.417899, -2.002308, 0.255245, -1.10515
# Out:
# Writing sample1.csv

# %%
df = pd.read_csv('C:/workspace/basic/sample1.csv', na_values = ['누락'])
print(df)
df.to_csv('sample3.csv', na_rep = '누락')
print("sample3.csv 파일 생성됨")
df.to_csv('sample4.csv', index = False, header = False)
print("sample4.csv 파일 생성됨")
# Out:
#          c1          c2        c3       c4
# 0  0.179181   -1.538472  1.347553  0.43381
# 1  1.024209             -1.281997  0.49265
# 2  0.417899   -2.002308  0.255245 -1.10515
# sample3.csv 파일 생성됨
# sample4.csv 파일 생성됨

# %% [markdown]
# # URL 다루기

# %%
# URL과 저장 경로 지정하기
url = "data:image/png;base64,..."
savename = "test.png"
# 다운로드
urllib.request.urlretrieve(url, savename)
print("저장되었습니다...!")
# Out:
# 저장되었습니다...!

# %%
with urllib.request.urlopen('http://python.org/') as response:
    with tempfile.NamedTemporaryFile(delete=False) as tmp_file:
        shutil.copyfileobj(response, tmp_file)
with open(tmp_file.name) as html:
    pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-1c53c45eea0b> in <module>
#       1 with urllib.request.urlopen('http://python.org/') as response:
# ----> 2     with temp_file.NamedTemporaryFile(delete=False) as tmp_file:
#       3         shutil.copyfileobj(response, tmp_file)
#       4 with open(tmp_file.name) as html:
#       5     pass
#
# NameError: name 'temp_file' is not defined

# %%
import urllib.request
import urllib.parse
API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"

# 매개변수를 URL 인코딩합니다.
#stnId는 기상 정보를 알고 싶은 지역
values = {'stnId': '109'}
params = urllib.parse.urlencode(values)

# 요청 전용 URL을 생성합니다. 
url = API + "?" + params
print("url=", url)

# 다운로드합니다. 
data = urllib.request.urlopen(url).read()
text = data.decode("utf-8")
print(text)
# Out:
# url= http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2021년 06월 05일 (토)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>서울,경기도 육상 중기예보 - 2021년 06월 05일 (토)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</guid>
# <description>
# 	<header>
# 		<title>서울,경기도 육상중기예보</title>
# 		<tm>202106050600</tm>
# 		<wf><![CDATA[○ (기온) 이번 예보기간 아침최저기온은 16~20도, 낮최고기온은 25~30도로 어제(4일, 아침최저기온 12~14도, 낮최고기온 20~25도)보다 높겠습니다. <br />          특히, 8일(화)~9일(수)은 내륙을 중심으로 낮 기온이 30도 이상 오르는 곳이 많아 덥겠습니다.<br />○ (해상) 서해중부해상의 물결은 0.5~2.0m로 일겠습니다.]]></wf>
# 	</header>
# 	<body>
#
#
# ...

# %%
import sys
import urllib.request as req
import urllib.parse as parse
# 명령줄 매개변수 추출
if len(sys.argv) <= 1:
    print("USAGE: download-forecast-argv <Region Number>")
    sys.exit() #실행중인 파이썬 코드(어플리케이션) 종료
regionNumber = sys.argv[1]
print(sys.argv)
print(type(sys.argv))
# 매개변수를 URL 인코딩합니다. 
API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
values = {
'stnId': regionNumber
}
params = parse.urlencode(values)
url = API + "?" + params
print("url=", url)
# 다운로드합니다. data = req.urlopen(url).read()
text = data.decode("utf-8")
#print(text)
# Out:
# ['C:\\Users\\korha\\anaconda3\\envs\\basic\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\korha\\AppData\\Roaming\\jupyter\\runtime\\kernel-f9385e13-a739-474a-ba0d-69a5246cb4bc.json']
# <class 'list'>
# url= http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=-f

# %%
from urllib.parse import urljoin
base = "http://example.com/html/a.html"

print( urljoin(base, "http://otherExample.com/wiki") )
print( urljoin(base, "//anotherExample.org/test") )
# Out:
# http://otherExample.com/wiki
# http://anotherExample.org/test

# %%
from urllib.parse import urljoin			
base = "http://example.com/html/a.html"
print( urljoin(base, "b.html") )
print( urljoin(base, "sub/c.html") )
print( urljoin(base, "../index.html") )
print( urljoin(base, "../img/hoge.png") )
print( urljoin(base, "../css/hoge.css") )
print( urljoin(base, "/hoge.html") )
print( urljoin(base, "http://otherExample.com/wiki") )
print( urljoin(base, "//anotherExample.org/test") )
# Out:
# http://example.com/html/b.html
# http://example.com/html/sub/c.html
# http://example.com/index.html
# http://example.com/img/hoge.png
# http://example.com/css/hoge.css
# http://example.com/hoge.html
# http://otherExample.com/wiki
# http://anotherExample.org/test
